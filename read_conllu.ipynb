# %% [markdown]
# ## Testando o módulo `conllu`
#
# Arquivo de teste e demo para analisar frases num aquivo no formato CONLLU.
#
# O arquivo conllu `tenSents.conllu` é composto pelas 10 primeiras frases do Bosque marcado em UD. Ainda não tentei processar o Porttinari Base com este código.
#
# Para ir direto ao ponto, veja o teste do módulo `pyconll` abaixo.

# %%
import conllu

# %% [markdown]
# Para teste, fiz um recorte de apenas 10 frases neste arquivo `tenSents.conllu`

# %%
data=open('data/porttinari-base/Porttinari-base_test.conllu', mode='r', encoding='utf-8')
notes=data.read()
type(notes)
# Out:
# str

# %%
#primeiros 200 caracteres
print(notes[:200])
# Out:
# # sent_id = FOLHA_DOC000123_SENT016
# # text = O Capitão América também bajulou o tucano.
# 1	O	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	_	_
# 2	Capitão	Capitão	PROPN	_	_	5	nsubj	_	_

# %%
sents=conllu.parse(notes)
print("# frases: " + str(len(sents)))
print(sents[0])
print(type(sents[0]))
# sents[0] é uma TokenList
# Out:
# # frases: 1683
# TokenList<O, Capitão, América, também, bajulou, o, tucano, ., metadata={sent_id: "FOLHA_DOC000123_SENT016", text: "O Capitão América também bajulou o tucano."}>
# <class 'conllu.models.TokenList'>

# %%
meta=sents[0].metadata
print(meta)
print(type(meta))
#metadata é um dicionário Python
print("Texto original: "+meta['text'])
print("ID da frase: "+meta['sent_id'])
# Out:
# {'sent_id': 'FOLHA_DOC000123_SENT016', 'text': 'O Capitão América também bajulou o tucano.'}
# <class 'conllu.models.Metadata'>
# Texto original: O Capitão América também bajulou o tucano.
# ID da frase: FOLHA_DOC000123_SENT016

# %%
print(sents[0][1]['upos'])
# Out:
# PROPN

# %% [markdown]
# ## Testando o módulo `pyconll`
# Outro módulo Python para tratamento de frases no formato CONLLU

# %%
import pyconll

frases = pyconll.load_from_file('data/porttinari-base/Porttinari-base_test.conllu')

review = []

# Conll objects are iterable over their sentences, and sentences are iterable
# over their tokens. Sentences also de/serialize comment information.
for sent in frases:
    lista_ud=[]
    for token in sent:
        # Tokens have attributes such as upos, head, id, deprel, etc,
        lista_ud.append((token.form, token.xpos, token.upos, token.deprel))
    review.append(lista_ud)

for ind in range(len(frases)):
    print(ind, review[ind])
# Out:
# 0 [('O', None, 'DET', 'det'), ('Capitão', None, 'PROPN', 'nsubj'), ('América', None, 'PROPN', 'flat:name'), ('também', None, 'ADV', 'advmod'), ('bajulou', None, 'VERB', 'root'), ('o', None, 'DET', 'det'), ('tucano', None, 'NOUN', 'obj'), ('.', None, 'PUNCT', 'punct')]
# 1 [('A', None, 'DET', 'det'), ('Odebrecht', None, 'PROPN', 'nsubj'), ('pagou', None, 'VERB', 'root'), ('300', None, 'NUM', 'nummod'), ('%', None, 'SYM', 'obj'), ('a', None, 'ADP', 'advmod'), ('mais', None, 'ADV', 'fixed'), ('pelo', None, None, None), ('por', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('direito', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'mark'), ('explorar', None, 'VERB', 'acl'), ('o', None, 'DET', 'det'), ('aeroporto', None, 'NOUN', 'obj'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('Galeão', None, 'PROPN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 2 [('No', None, None, None), ('Em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('começo', None, 'NOUN', 'obl'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('século', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('a', None, 'DET', 'det'), ('JBS/Friboi', None, 'PROPN', 'nsubj'), ('chegava', None, 'VERB', 'root'), ('ao', None, None, None), ('a', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('grupo', None, 'NOUN', 'obl'), ('das', None, None, None), ('de', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('400', None, 'NUM', 'nmod'), ('maiores', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# 3 [('Os', None, 'DET', 'det'), ('sons', None, 'NOUN', 'nsubj:pass'), ('indesejáveis', None, 'ADJ', 'amod'), ('emitidos', None, 'VERB', 'acl'), ('por', None, 'ADP', 'case'), ('uma', None, 'DET', 'det'), ('porta', None, 'NOUN', 'obl:agent'), (',', None, 'PUNCT', 'punct'), ('por', None, 'ADP', 'case'), ('exemplo', None, 'NOUN', 'obl'), (',', None, 'PUNCT', 'punct'), ('são', None, 'AUX', 'aux:pass'), ('eliminados', None, 'VERB', 'root'), ('por', None, 'ADP', 'case'), ('R$', None, 'SYM', 'obl'), ('150', None, 'NUM', 'nummod'), ('.', None, 'PUNCT', 'punct')]
# 4 [('Que', None, 'PRON', 'nsubj'), ('foi', None, 'AUX', 'cop'), ('herança', None, 'NOUN', 'ccomp:speech'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('PT', None, 'PROPN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('que', None, 'PRON', 'nsubj'), ('nos', None, 'PRON', 'obl'), ('deixou', None, 'VERB', 'acl:relcl'), ('esse', None, 'DET', 'det'), ('rombo', None, 'NOUN', 'obj'), (',', None, 'PUNCT', 'punct'), ('disse', None, 'VERB', 'root'), ('Doria', None, 'PROPN', 'nsubj'), ('.', None, 'PUNCT', 'punct')]
# 5 [('O', None, 'DET', 'det'), ('departamento', None, 'NOUN', 'nsubj'), ('médico', None, 'ADJ', 'amod'), ('santista', None, 'ADJ', 'amod'), ('também', None, 'ADV', 'advmod'), ('já', None, 'ADV', 'advmod'), ('colocou', None, 'VERB', 'root'), ('o', None, 'DET', 'det'), ('atleta', None, 'NOUN', 'obj'), ('para', None, 'ADP', 'mark'), ('ter', None, 'VERB', 'advcl'), ('o', None, 'DET', 'det'), ('acompanhamento', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'case'), ('uma', None, 'DET', 'det'), ('psicóloga', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 6 [('Por', None, 'ADP', 'case'), ('que', None, 'PRON', 'obl'), ('é', None, 'AUX', 'cop'), ('mais', None, 'ADV', 'advmod'), ('difícil', None, 'ADJ', 'root'), ('para', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('mulheres', None, 'NOUN', 'obl'), ('lutar', None, 'VERB', 'csubj'), ('contra', None, 'ADP', 'case'), ('alcoolismo', None, 'NOUN', 'obl'), ('e', None, 'CCONJ', 'cc'), ('dependência', None, 'NOUN', 'conj'), ('às', None, None, None), ('a', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('drogas', None, 'NOUN', 'nmod'), ('?', None, 'PUNCT', 'punct')]
# 7 [('Outra', None, 'DET', 'det'), ('etiqueta', None, 'NOUN', 'advcl'), ('das', None, None, None), ('de', None, 'ADP', 'case'), ('as', None, 'PRON', 'nmod'), ('mais', None, 'ADV', 'advmod'), ('clássicas', None, 'ADJ', 'amod'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('calendário', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('a', None, 'DET', 'det'), ('Bottega', None, 'PROPN', 'nsubj'), ('Venetta', None, 'PROPN', 'flat:name'), ('construiu', None, 'VERB', 'root'), ('com', None, 'ADP', 'case'), ('base', None, 'NOUN', 'obl'), ('nas', None, None, None), ('em', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('pintas', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('leopardo', None, 'NOUN', 'nmod'), ('a', None, 'DET', 'det'), ('imagem', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'case'), ('amazona', None, 'NOUN', 'nmod'), ('moderna', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# 8 [('Não', None, 'ADV', 'advmod'), ('é', None, 'AUX', 'cop'), ('biodegradável', None, 'ADJ', 'root'), ('e', None, 'CCONJ', 'cc'), (',', None, 'PUNCT', 'punct'), ('para', None, 'ADP', 'mark'), ('produzí-lo', None, None, None), ('produzir', None, 'VERB', 'advcl'), ('lo', None, 'PRON', 'obj'), (',', None, 'PUNCT', 'punct'), ('é', None, 'AUX', 'cop'), ('necessário', None, 'ADJ', 'conj'), ('expandir', None, 'VERB', 'csubj'), ('ainda', None, 'ADV', 'advmod'), ('mais', None, 'ADV', 'advmod'), ('a', None, 'DET', 'det'), ('agricultura', None, 'NOUN', 'obj'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('cana', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 9 [('"', None, 'PUNCT', 'punct'), ('Temos', None, 'VERB', 'ccomp:speech'), ('segurança', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'mark'), ('que', None, 'SCONJ', 'fixed'), ('(', None, 'PUNCT', 'punct'), ('...', None, 'PUNCT', 'punct'), (')', None, 'PUNCT', 'punct'), ('são', None, 'AUX', 'cop'), ('íntegros', None, 'ADJ', 'acl'), ('"', None, 'PUNCT', 'punct'), (',', None, 'PUNCT', 'punct'), ('diz', None, 'VERB', 'root'), ('o', None, 'DET', 'det'), ('texto', None, 'NOUN', 'nsubj'), ('.', None, 'PUNCT', 'punct')]
# 10 [('Infelizmente', None, 'ADV', 'advmod'), (',', None, 'PUNCT', 'punct'), ('a', None, 'DET', 'det'), ('duquesa', None, 'NOUN', 'nsubj'), ('de', None, 'ADP', 'case'), ('Cambridge', None, 'PROPN', 'nmod'), ('ainda', None, 'ADV', 'advmod'), ('não', None, 'ADV', 'advmod'), ('está', None, 'AUX', 'cop'), ('bem', None, 'ADV', 'root'), ('e', None, 'CCONJ', 'cc'), ('não', None, 'ADV', 'advmod'), ('poderá', None, 'VERB', 'conj'), ('conduzir', None, 'VERB', 'xcomp'), ('o', None, 'DET', 'det'), ('príncipe', None, 'NOUN', 'obj'), ('George', None, 'PROPN', 'nmod'), ('no', None, None, None), ('em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('seu', None, 'DET', 'det'), ('primeiro', None, 'ADJ', 'amod'), ('dia', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('colégio', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 11 [('As', None, 'DET', 'det'), ('pessoas', None, 'NOUN', 'nsubj'), ('físicas', None, 'ADJ', 'amod'), ('foram', None, 'AUX', 'cop'), ('muito', None, 'ADV', 'advmod'), ('importantes', None, 'ADJ', 'root'), ('para', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('indústria', None, 'NOUN', 'obl'), ('e', None, 'CCONJ', 'cc'), ('vão', None, 'AUX', 'aux'), ('continuar', None, 'VERB', 'conj'), ('sendo', None, 'AUX', 'xcomp'), ('daqui', None, None, None), ('de', None, 'ADP', 'case'), ('aqui', None, 'ADV', 'advmod'), ('para', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('frente', None, 'NOUN', 'obl'), (',', None, 'PUNCT', 'punct'), ('quando', None, 'SCONJ', 'mark'), ('tivermos', None, 'VERB', 'advcl'), ('um', None, 'DET', 'det'), ('patamar', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'case'), ('juros', None, 'NOUN', 'nmod'), ('mais', None, 'ADV', 'advmod'), ('baixo', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# 12 [('No', None, None, None), ('Em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('período', None, 'NOUN', 'obl'), (',', None, 'PUNCT', 'punct'), ('25', None, 'NUM', 'nummod'), ('atrações', None, 'NOUN', 'nsubj'), ('continuam', None, 'VERB', 'root'), ('em', None, 'ADP', 'case'), ('funcionamento', None, 'NOUN', 'obl'), (',', None, 'PUNCT', 'punct'), ('além', None, 'ADV', 'advmod'), ('de', None, 'ADP', 'case'), ('encontros', None, 'NOUN', 'obl'), ('com', None, 'ADP', 'case'), ('personagens', None, 'NOUN', 'nmod'), ('e', None, 'CCONJ', 'cc'), ('shows', None, 'NOUN', 'conj'), ('especiais', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# 13 [('Como', None, 'SCONJ', 'mark'), ('na', None, None, None), ('em', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('piada', None, 'NOUN', 'advcl'), (',', None, 'PUNCT', 'punct'), ('a', None, 'DET', 'det'), ('saída', None, 'NOUN', 'nsubj'), ('para', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('crise', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('insegurança', None, 'NOUN', 'nmod'), ('está', None, 'AUX', 'cop'), ('no', None, None, None), ('em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('aeroporto', None, 'NOUN', 'root'), ('.', None, 'PUNCT', 'punct')]
# 14 [('Aí', None, 'ADV', 'advmod'), ('veio', None, 'VERB', 'root'), ('a', None, 'DET', 'det'), ('chave', None, 'NOUN', 'nsubj'), ('estética', None, 'ADJ', 'amod'), (',', None, 'PUNCT', 'punct'), ('que', None, 'PRON', 'nsubj'), ('remetia', None, 'VERB', 'acl:relcl'), ('imediatamente', None, 'ADV', 'advmod'), ('ao', None, None, None), ('a', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('disco', None, 'NOUN', 'obl'), ('anterior', None, 'ADJ', 'amod'), (',', None, 'PUNCT', 'punct'), ('ao', None, None, None), ('a', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('"', None, 'PUNCT', 'punct'), ('Refazenda', None, 'PROPN', 'appos'), ('"', None, 'PUNCT', 'punct'), ('.', None, 'PUNCT', 'punct')]
# 15 [('Um', None, 'DET', 'det'), ('exemplo', None, 'NOUN', 'nsubj'), ('é', None, 'AUX', 'cop'), ('o', None, 'DET', 'det'), ('ataque', None, 'NOUN', 'root'), ('à', None, None, None), ('a', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('política', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('crédito', None, 'NOUN', 'nmod'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('BNDES', None, 'PROPN', 'nmod'), ('nos', None, None, None), ('em', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('governos', None, 'NOUN', 'nmod'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('PT', None, 'PROPN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 16 [('Com', None, 'ADP', 'case'), ('mais', None, 'DET', 'det'), ('tempo', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('treino', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('o', None, 'DET', 'det'), ('Palmeiras', None, 'PROPN', 'nsubj'), ('está', None, 'AUX', 'cop'), ('melhor', None, 'ADJ', 'root'), ('.', None, 'PUNCT', 'punct')]
# 17 [('Fingindo', None, 'VERB', 'advcl'), ('que', None, 'SCONJ', 'mark'), ('não', None, 'ADV', 'advmod'), ('via', None, 'VERB', 'ccomp'), ('a', None, 'DET', 'det'), ('corrupção', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'case'), ('direita', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('o', None, 'DET', 'det'), ('MBL', None, 'PROPN', 'nsubj'), ('perdeu', None, 'VERB', 'root'), ('a', None, 'DET', 'det'), ('bandeira', None, 'NOUN', 'obj'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('moralidade', None, 'NOUN', 'nmod'), ('pública', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# 18 [('A', None, 'DET', 'det'), ('torre', None, 'NOUN', 'nsubj'), (',', None, 'PUNCT', 'punct'), ('no', None, None, None), ('em', None, 'ADP', 'cc'), ('o', None, 'DET', 'fixed'), ('entanto', None, 'NOUN', 'fixed'), (',', None, 'PUNCT', 'punct'), ('não', None, 'ADV', 'advmod'), ('ficará', None, 'VERB', 'root'), ('no', None, None, None), ('em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('escuro', None, 'NOUN', 'obl'), ('enquanto', None, 'SCONJ', 'mark'), ('a', None, 'DET', 'det'), ('manutenção', None, 'NOUN', 'nsubj'), ('acontece', None, 'VERB', 'advcl'), ('.', None, 'PUNCT', 'punct')]
# 19 [('Para', None, 'ADP', 'case'), ('ele', None, 'PRON', 'obl'), (',', None, 'PUNCT', 'punct'), ('isso', None, 'PRON', 'nsubj'), ('tudo', None, 'PRON', 'fixed'), ('só', None, 'ADV', 'advmod'), ('ocorreu', None, 'VERB', 'root'), ('por', None, 'ADP', 'case'), ('conta', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('"', None, 'PUNCT', 'punct'), ('sucessão', None, 'NOUN', 'nmod'), ('desastrosa', None, 'ADJ', 'amod'), ('de', None, 'ADP', 'case'), ('equívocos', None, 'NOUN', 'nmod'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('DHPP', None, 'PROPN', 'nmod'), ('"', None, 'PUNCT', 'punct'), (',', None, 'PUNCT', 'punct'), ('originados', None, 'VERB', 'acl'), ('por', None, 'ADP', 'case'), ('uma', None, 'DET', 'det'), ('pressão', None, 'NOUN', 'obl:agent'), ('política', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# 20 [('Você', None, 'PRON', 'dislocated'), (',', None, 'PUNCT', 'punct'), ('por', None, 'ADP', 'case'), ('exemplo', None, 'NOUN', 'obl'), (',', None, 'PUNCT', 'punct'), ('você', None, 'PRON', 'nsubj'), ('brilha', None, 'VERB', 'root'), ('um', None, 'DET', 'det'), ('pouco', None, 'NOUN', 'obl'), ('.', None, 'PUNCT', 'punct')]
# 21 [('A', None, 'DET', 'det'), ('gente', None, 'NOUN', 'nsubj'), ('vai', None, 'AUX', 'aux'), ('comprar', None, 'VERB', 'root'), ('pão', None, 'NOUN', 'obj'), ('e', None, 'CCONJ', 'cc'), ('fica', None, 'VERB', 'conj'), ('ouvindo', None, 'VERB', 'xcomp'), ('muita', None, 'ADJ', 'amod'), ('coisinha', None, 'NOUN', 'obj'), ('.', None, 'PUNCT', 'punct')]
# 22 [('Nos', None, None, None), ('Em', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('anos', None, 'NOUN', 'obl'), ('1990', None, 'NUM', 'nmod'), (',', None, 'PUNCT', 'punct'), ('tínhamos', None, 'VERB', 'root'), ('uma', None, 'DET', 'det'), ('perspectiva', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'case'), ('um', None, 'DET', 'det'), ('mundo', None, 'NOUN', 'nmod'), ('sem', None, 'ADP', 'case'), ('fronteiras', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('algo', None, 'PRON', 'appos'), ('que', None, 'PRON', 'nsubj'), ('nos', None, None, None), ('em', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('anos', None, 'NOUN', 'obl'), ('1980', None, 'NUM', 'nmod'), ('era', None, 'AUX', 'cop'), ('inimaginável', None, 'ADJ', 'acl:relcl'), ('.', None, 'PUNCT', 'punct')]
# 23 [('Como', None, 'ADV', 'advmod'), ('é', None, 'AUX', 'cop'), ('possível', None, 'ADJ', 'root'), ('adaptá-lo', None, None, None), ('adaptar', None, 'VERB', 'csubj'), ('lo', None, 'PRON', 'obj'), ('para', None, 'ADP', 'case'), ('outros', None, 'DET', 'det'), ('contextos', None, 'NOUN', 'obl'), ('socioeconômicos', None, 'ADJ', 'amod'), ('?', None, 'PUNCT', 'punct')]
# 24 [('As', None, 'DET', 'det'), ('pessoas', None, 'NOUN', 'nsubj'), ('têm', None, 'VERB', 'root'), ('a', None, 'DET', 'det'), ('sensação', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'mark'), ('que', None, 'SCONJ', 'fixed'), ('é', None, 'AUX', 'cop'), ('fácil', None, 'ADJ', 'acl'), ('fortificar', None, 'VERB', 'csubj'), ('suas', None, 'DET', 'det'), ('fronteiras', None, 'NOUN', 'obj'), ('e', None, 'CCONJ', 'cc'), ('que', None, 'SCONJ', 'mark'), ('isso', None, 'PRON', 'nsubj'), ('vai', None, 'AUX', 'aux'), ('protegê-las', None, None, None), ('proteger', None, 'VERB', 'conj'), ('las', None, 'PRON', 'obj'), ('das', None, None, None), ('de', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('ameaças', None, 'NOUN', 'obl'), ('e', None, 'CCONJ', 'cc'), ('riscos', None, 'NOUN', 'conj'), ('globais', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# 25 [('Esses', None, 'PRON', 'nsubj'), ('são', None, 'AUX', 'cop'), ('alguns', None, 'DET', 'det'), ('detalhes', None, 'NOUN', 'root'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('nova', None, 'ADJ', 'amod'), ('pesquisa', None, 'NOUN', 'nmod'), ('Datafolha', None, 'PROPN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 26 [('Na', None, None, None), ('Em', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('visão', None, 'NOUN', 'obl'), ('feminista', None, 'ADJ', 'amod'), ('atual', None, 'ADJ', 'amod'), ('a', None, 'DET', 'det'), ('música', None, 'NOUN', 'nsubj'), ('é', None, 'AUX', 'cop'), ('machista', None, 'ADJ', 'root'), (',', None, 'PUNCT', 'punct'), ('objetifica', None, 'VERB', 'parataxis'), ('a', None, 'DET', 'det'), ('mulher', None, 'NOUN', 'obj'), ('.', None, 'PUNCT', 'punct')]
# 27 [('Os', None, 'DET', 'det'), ('ministros', None, 'NOUN', 'nsubj'), ('Gilmar', None, 'PROPN', 'nmod'), ('Mendes', None, 'PROPN', 'flat:name'), (',', None, 'PUNCT', 'punct'), ('Dias', None, 'PROPN', 'conj'), ('Toffoli', None, 'PROPN', 'flat:name'), (',', None, 'PUNCT', 'punct'), ('Alexandre', None, 'PROPN', 'conj'), ('de', None, 'ADP', 'case'), ('Moraes', None, 'PROPN', 'flat:name'), ('e', None, 'CCONJ', 'cc'), ('Ricardo', None, 'PROPN', 'conj'), ('Lewandowski', None, 'PROPN', 'flat:name'), ('não', None, 'ADV', 'advmod'), ('participaram', None, 'VERB', 'root'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('sessão', None, 'NOUN', 'obl'), ('.', None, 'PUNCT', 'punct')]
# 28 [('Os', None, 'DET', 'det'), ('aeroportos', None, 'NOUN', 'nsubj:pass'), ('seriam', None, 'AUX', 'aux:pass'), ('licitados', None, 'VERB', 'root'), ('em', None, 'ADP', 'case'), ('seis', None, 'NUM', 'nummod'), ('blocos', None, 'NOUN', 'obl'), (',', None, 'PUNCT', 'punct'), ('com', None, 'ADP', 'case'), ('operações', None, 'NOUN', 'obl'), ('lucrativas', None, 'ADJ', 'amod'), ('e', None, 'CCONJ', 'cc'), ('deficitárias', None, 'ADJ', 'conj'), ('em', None, 'ADP', 'case'), ('cada', None, 'DET', 'det'), ('um', None, 'PRON', 'nmod'), ('deles', None, None, None), ('de', None, 'ADP', 'case'), ('eles', None, 'PRON', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 29 [('Para', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('presidente', None, 'NOUN', 'obl'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('ANPR', None, 'PROPN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('o', None, 'DET', 'det'), ('procurador-geral', None, 'NOUN', 'nsubj'), ('"', None, 'PUNCT', 'punct'), ('cumpriu', None, 'VERB', 'root'), ('seu', None, 'DET', 'det'), ('dever', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'case'), ('maneira', None, 'NOUN', 'obl'), ('extremamente', None, 'ADV', 'advmod'), ('correta', None, 'ADJ', 'amod'), ('"', None, 'PUNCT', 'punct'), ('e', None, 'CCONJ', 'cc'), ('"', None, 'PUNCT', 'punct'), ('qualquer', None, 'DET', 'det'), ('tropeço', None, 'NOUN', 'nsubj'), ('que', None, 'PRON', 'nsubj'), ('tenha', None, 'AUX', 'aux'), ('sofrido', None, 'VERB', 'acl:relcl'), ('no', None, None, None), ('em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('final', None, 'NOUN', 'obl'), ('não', None, 'ADV', 'advmod'), ('apaga', None, 'VERB', 'conj'), ('o', None, 'DET', 'det'), ('seu', None, 'DET', 'det'), ('legado', None, 'NOUN', 'obj'), ('"', None, 'PUNCT', 'punct'), ('.', None, 'PUNCT', 'punct')]
# 30 [('A', None, 'DET', 'det'), ('organização', None, 'NOUN', 'nsubj'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('festival', None, 'NOUN', 'nmod'), ('não', None, 'ADV', 'advmod'), ('informa', None, 'VERB', 'root'), ('quanto', None, 'ADV', 'advmod'), ('pagou', None, 'VERB', 'ccomp'), ('a', None, 'ADP', 'case'), ('nenhum', None, 'PRON', 'obl'), ('dos', None, None, None), ('de', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('participantes', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 31 [('FI-FGTS', None, 'PROPN', 'nsubj:pass'), ('[', None, 'PUNCT', 'punct'), ('linha', None, 'NOUN', 'appos'), ('de', None, 'ADP', 'case'), ('financiamentos', None, 'NOUN', 'nmod'), ('que', None, 'PRON', 'nsubj:pass'), ('seria', None, 'AUX', 'aux:pass'), ('liberada', None, 'VERB', 'acl:relcl'), ('à', None, None, None), ('a', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('base', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('propina', None, 'NOUN', 'nmod'), (']', None, 'PUNCT', 'punct'), ('foi', None, 'AUX', 'aux:pass'), ('criado', None, 'VERB', 'root'), ('pelo', None, None, None), ('por', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('presidente', None, 'NOUN', 'obl:agent'), ('Lula', None, 'PROPN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 32 [('Deve', None, 'VERB', 'ccomp:speech'), ('ser', None, 'AUX', 'aux:pass'), ('encarado', None, 'VERB', 'xcomp'), ('como', None, 'ADP', 'case'), ('uma', None, 'DET', 'det'), ('estratégia', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('diversificação', None, 'NOUN', 'nmod'), ('extrema', None, 'ADJ', 'amod'), (',', None, 'PUNCT', 'punct'), ('afirma', None, 'VERB', 'root'), ('o', None, 'DET', 'det'), ('planejador', None, 'NOUN', 'nsubj'), ('financeiro', None, 'ADJ', 'amod'), ('Janser', None, 'PROPN', 'nmod'), ('Rojo', None, 'PROPN', 'flat:name'), (',', None, 'PUNCT', 'punct'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('associação', None, 'NOUN', 'nmod'), ('Planejar', None, 'PROPN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 33 [('Ainda', None, 'ADV', 'advmod'), ('não', None, 'ADV', 'advmod'), ('sabemos', None, 'VERB', 'root'), ('a', None, 'ADP', 'case'), ('onde', None, 'ADV', 'advmod'), ('esse', None, 'DET', 'det'), ('populismo', None, 'NOUN', 'nsubj'), ('nos', None, 'PRON', 'obj'), ('levará', None, 'VERB', 'ccomp'), ('.', None, 'PUNCT', 'punct')]
# 34 [('Trabalho', None, 'NOUN', 'root'), ('para', None, 'ADP', 'case'), ('milhares', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('senão', None, 'CCONJ', 'cc'), ('milhões', None, 'NOUN', 'conj'), (',', None, 'PUNCT', 'punct'), ('de', None, 'ADP', 'case'), ('anos', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 35 [('O', None, 'DET', 'det'), ('país', None, 'NOUN', 'nsubj'), ('onde', None, 'ADV', 'advmod'), ('estou', None, 'AUX', 'cop'), ('protegido', None, 'ADJ', 'acl:relcl'), ('é', None, 'AUX', 'cop'), ('aqui', None, 'ADV', 'ccomp:speech'), (',', None, 'PUNCT', 'punct'), ('afirmou', None, 'VERB', 'root'), ('ele', None, 'PRON', 'nsubj'), (',', None, 'PUNCT', 'punct'), ('negando', None, 'VERB', 'advcl'), ('que', None, 'SCONJ', 'mark'), ('tivesse', None, 'VERB', 'ccomp'), ('a', None, 'DET', 'det'), ('intenção', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'mark'), ('fugir', None, 'VERB', 'acl'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('país', None, 'NOUN', 'obl'), ('.', None, 'PUNCT', 'punct')]
# 36 [('Putin', None, 'PROPN', 'nsubj'), ('redesenha', None, 'VERB', 'root'), ('os', None, 'DET', 'det'), ('caminhos', None, 'NOUN', 'obj'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('Oriente', None, 'PROPN', 'nmod'), ('Médio', None, 'PROPN', 'flat:name'), ('a', None, 'ADP', 'mark'), ('partir', None, 'VERB', 'advcl'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('intervenção', None, 'NOUN', 'obl'), ('na', None, None, None), ('em', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('Síria', None, 'PROPN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 37 [('Crise', None, 'NOUN', 'nsubj'), ('dos', None, None, None), ('de', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('Estados', None, 'PROPN', 'nmod'), ('Unidos', None, 'PROPN', 'flat:name'), ('elimina', None, 'VERB', 'root'), ('1,5', None, 'NUM', 'nummod'), ('milhão', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'case'), ('vagas', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('emprego', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 38 [('"', None, 'PUNCT', 'punct'), ('Acredito', None, 'VERB', 'ccomp:speech'), ('que', None, 'SCONJ', 'mark'), ('eu', None, 'PRON', 'nsubj'), ('e', None, 'CCONJ', 'cc'), ('o', None, 'DET', 'det'), ('presidente', None, 'NOUN', 'conj'), ('Xi', None, 'PROPN', 'nmod'), ('concordamos', None, 'VERB', 'ccomp'), ('em', None, 'ADP', 'case'), ('100', None, 'NUM', 'nummod'), ('%', None, 'SYM', 'obl'), ('"', None, 'PUNCT', 'punct'), (',', None, 'PUNCT', 'punct'), ('disse', None, 'VERB', 'root'), ('o', None, 'DET', 'det'), ('americano', None, 'NOUN', 'nsubj'), ('a', None, 'ADP', 'case'), ('repórteres', None, 'NOUN', 'obl'), ('.', None, 'PUNCT', 'punct')]
# 39 [('Assim', None, 'ADV', 'cc'), ('como', None, 'SCONJ', 'fixed'), ('não', None, 'ADV', 'advmod'), ('é', None, 'AUX', 'cop'), ('preciso', None, 'ADJ', 'root'), ('ser', None, 'AUX', 'cop'), ('católico', None, 'ADJ', 'csubj'), ('para', None, 'ADP', 'mark'), ('exclamar', None, 'VERB', 'advcl'), ('"', None, 'PUNCT', 'punct'), ('Nossa', None, 'INTJ', 'ccomp:speech'), ('!', None, 'PUNCT', 'punct'), ('"', None, 'PUNCT', 'punct'), ('.', None, 'PUNCT', 'punct')]
# 40 [('Se', None, 'SCONJ', 'mark'), ('é', None, 'AUX', 'cop'), ('verdade', None, 'NOUN', 'advcl'), ('que', None, 'SCONJ', 'mark'), ('criador', None, 'NOUN', 'nsubj'), ('e', None, 'CCONJ', 'cc'), ('criatura', None, 'NOUN', 'conj'), ('tendem', None, 'VERB', 'csubj'), ('a', None, 'ADP', 'mark'), ('estar', None, 'AUX', 'cop'), ('juntos', None, 'ADJ', 'xcomp'), ('em', None, 'ADP', 'case'), ('2018', None, 'NUM', 'obl'), (',', None, 'PUNCT', 'punct'), ('nunca', None, 'ADV', 'advmod'), ('é', None, 'AUX', 'cop'), ('descartável', None, 'ADJ', 'root'), ('a', None, 'DET', 'det'), ('ruptura', None, 'NOUN', 'nsubj'), ('.', None, 'PUNCT', 'punct')]
# 41 [('Banhado', None, 'VERB', 'advcl'), ('pelas', None, None, None), ('por', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('lagoas', None, 'NOUN', 'obl:agent'), ('Mundaú', None, 'PROPN', 'nmod'), ('e', None, 'CCONJ', 'cc'), ('Manguaba', None, 'PROPN', 'conj'), (',', None, 'PUNCT', 'punct'), ('é', None, 'AUX', 'cop'), ('de', None, 'ADP', 'case'), ('grande', None, 'ADJ', 'amod'), ('referência', None, 'NOUN', 'root'), ('histórica', None, 'ADJ', 'amod'), ('e', None, 'CCONJ', 'cc'), ('belezas', None, 'NOUN', 'conj'), ('naturais', None, 'ADJ', 'amod'), ('para', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('turistas', None, 'NOUN', 'nmod'), ('que', None, 'PRON', 'nsubj'), ('chegam', None, 'VERB', 'acl:relcl'), ('a', None, 'ADP', 'case'), ('Alagoas', None, 'PROPN', 'obl'), ('.', None, 'PUNCT', 'punct')]
# 42 [('Diversos', None, 'DET', 'det'), ('estudiosos', None, 'NOUN', 'nsubj'), ('têm', None, 'AUX', 'aux'), ('apontado', None, 'VERB', 'root'), ('para', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('passado', None, 'NOUN', 'obl'), ('escravagista', None, 'ADJ', 'amod'), ('e', None, 'CCONJ', 'cc'), ('patrimonialista', None, 'ADJ', 'conj'), ('como', None, 'ADP', 'case'), ('marcas', None, 'NOUN', 'obl'), ('ainda', None, 'ADV', 'advmod'), ('persistentes', None, 'ADJ', 'amod'), ('das', None, None, None), ('de', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('nossas', None, 'DET', 'det'), ('desigualdades', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 43 [('O', None, 'DET', 'det'), ('veredicto', None, 'NOUN', 'nsubj:outer'), ('é', None, 'AUX', 'cop'), ('que', None, 'SCONJ', 'mark'), ('a', None, 'DET', 'det'), ('comparação', None, 'NOUN', 'nsubj'), ('entre', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('duas', None, 'NUM', 'nummod'), ('festas', None, 'NOUN', 'nmod'), ('é', None, 'AUX', 'cop'), ('(', None, 'PUNCT', 'punct'), ('ainda', None, 'ADV', 'advmod'), (')', None, 'PUNCT', 'punct'), ('quase', None, 'ADV', 'advmod'), ('cruel', None, 'ADJ', 'root'), ('.', None, 'PUNCT', 'punct')]
# 44 [('Em', None, 'ADP', 'case'), ('um', None, 'DET', 'det'), ('futuro', None, 'NOUN', 'obl'), ('distópico', None, 'ADJ', 'amod'), ('dominado', None, 'VERB', 'acl'), ('por', None, 'ADP', 'case'), ('fascistas', None, 'NOUN', 'obl:agent'), (',', None, 'PUNCT', 'punct'), ('a', None, 'DET', 'det'), ('personagem', None, 'NOUN', 'nsubj'), ('de', None, 'ADP', 'case'), ('Moss', None, 'PROPN', 'nmod'), ('é', None, 'AUX', 'cop'), ('submetida', None, 'VERB', 'root'), ('a', None, 'ADP', 'case'), ('situações', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('muita', None, 'ADJ', 'amod'), ('violência', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 45 [('"', None, 'PUNCT', 'punct'), ('Foi', None, 'AUX', 'cop'), ('um', None, 'DET', 'det'), ('semestre', None, 'NOUN', 'ccomp:speech'), ('ímpar', None, 'ADJ', 'amod'), ('"', None, 'PUNCT', 'punct'), (',', None, 'PUNCT', 'punct'), ('diz', None, 'VERB', 'root'), ('Antônio', None, 'PROPN', 'nsubj'), ('Camardelli', None, 'PROPN', 'flat:name'), (',', None, 'PUNCT', 'punct'), ('presidente', None, 'NOUN', 'appos'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('Abiec', None, 'PROPN', 'nmod'), ('(', None, 'PUNCT', 'punct'), ('associação', None, 'NOUN', 'appos'), ('de', None, 'ADP', 'case'), ('exportadores', None, 'NOUN', 'nmod'), (')', None, 'PUNCT', 'punct'), ('.', None, 'PUNCT', 'punct')]
# 46 [('O', None, 'DET', 'det'), ('time', None, 'NOUN', 'nsubj'), ('francês', None, 'ADJ', 'amod'), ('tem', None, 'VERB', 'root'), ('boas', None, 'ADJ', 'amod'), ('possibilidades', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'mark'), ('suplantar', None, 'VERB', 'acl'), ('os', None, 'DET', 'det'), ('grandes', None, 'ADJ', 'amod'), ('ingleses', None, 'NOUN', 'obj'), (',', None, 'PUNCT', 'punct'), ('a', None, 'DET', 'det'), ('Juventus', None, 'PROPN', 'conj'), (',', None, 'PUNCT', 'punct'), ('o', None, 'DET', 'det'), ('Atlético', None, 'PROPN', 'conj'), ('de', None, 'ADP', 'case'), ('Madri', None, 'PROPN', 'nmod'), ('e', None, 'CCONJ', 'cc'), ('até', None, 'ADV', 'case'), ('o', None, 'DET', 'det'), ('Bayern', None, 'PROPN', 'conj'), ('de', None, 'ADP', 'case'), ('Munique', None, 'PROPN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('por', None, 'ADP', 'mark'), ('não', None, 'ADV', 'advmod'), ('terem', None, 'VERB', 'advcl'), ('um', None, 'DET', 'det'), ('Neymar', None, 'PROPN', 'obj'), ('.', None, 'PUNCT', 'punct')]
# 47 [('No', None, None, None), ('Em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('sistema', None, 'NOUN', 'obl'), ('distrital', None, 'ADJ', 'amod'), ('puro', None, 'ADJ', 'amod'), (',', None, 'PUNCT', 'punct'), ('todos', None, 'DET', 'det'), ('os', None, 'DET', 'det'), ('513', None, 'NUM', 'nummod'), ('deputados', None, 'NOUN', 'nsubj:pass'), ('seriam', None, 'AUX', 'aux:pass'), ('eleitos', None, 'VERB', 'root'), ('pela', None, None, None), ('por', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('votação', None, 'NOUN', 'obl'), ('direta', None, 'ADJ', 'amod'), ('dos', None, None, None), ('de', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('eleitores', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('seu', None, 'DET', 'det'), ('distrito', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 48 [('Ainda', None, 'ADV', 'advmod'), ('em', None, 'ADP', 'case'), ('nível', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('expectativa', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('há', None, 'VERB', 'root'), ('mais', None, 'ADV', 'advmod'), ('quatro', None, 'NUM', 'nummod'), ('ou', None, 'CCONJ', 'cc'), ('cinco', None, 'NUM', 'conj'), ('gravações', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'case'), ('Joesley', None, 'PROPN', 'nmod'), ('e', None, 'CCONJ', 'cc'), ('outros', None, 'DET', 'det'), ('dirigentes', None, 'NOUN', 'conj'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('grupo', None, 'NOUN', 'nmod'), ('J&F', None, 'PROPN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 49 [('Elas', None, 'PRON', 'nsubj'), ('o', None, 'PRON', 'obj'), ('situavam', None, 'VERB', 'root'), ('aqui', None, 'ADV', 'advmod'), ('ou', None, 'CCONJ', 'cc'), ('aqui', None, 'ADV', 'conj'), (',', None, 'PUNCT', 'punct'), ('mas', None, 'CCONJ', 'cc'), ('ninguém', None, 'PRON', 'nsubj'), ('sabia', None, 'VERB', 'conj'), ('ao', None, None, None), ('a', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('certo', None, 'NOUN', 'obl'), ('onde', None, 'ADV', 'ccomp'), ('ele', None, 'PRON', 'nsubj'), ('estava', None, 'AUX', 'cop'), ('.', None, 'PUNCT', 'punct')]
# 50 [('Vejo', None, 'VERB', 'root'), ('como', None, 'ADP', 'case'), ('absolutamente', None, 'ADV', 'advmod'), ('normal', None, 'ADJ', 'obl'), ('e', None, 'CCONJ', 'cc'), ('louvável', None, 'ADJ', 'conj'), ('a', None, 'DET', 'det'), ('atitude', None, 'NOUN', 'obj'), ('das', None, None, None), ('de', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('meninas', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'mark'), ('defenderem', None, 'VERB', 'acl'), ('a', None, 'DET', 'det'), ('continuidade', None, 'NOUN', 'obj'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('trabalho', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 51 [('Entre', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('exigências', None, 'NOUN', 'root'), ('de', None, 'ADP', 'case'), ('Trump', None, 'PROPN', 'nmod'), ('estão', None, 'AUX', 'cop'), ('também', None, 'ADV', 'advmod'), ('a', None, 'DET', 'det'), ('contratação', None, 'NOUN', 'nsubj'), ('de', None, 'ADP', 'case'), ('mais', None, 'ADV', 'advmod'), ('10', None, 'NUM', 'nummod'), ('mil', None, 'NUM', 'flat'), ('agentes', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('imigração', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('o', None, 'DET', 'det'), ('uso', None, 'NOUN', 'conj'), ('de', None, 'ADP', 'case'), ('um', None, 'DET', 'det'), ('sistema', None, 'NOUN', 'nmod'), ('que', None, 'PRON', 'nsubj'), ('dificulta', None, 'VERB', 'acl:relcl'), ('que', None, 'SCONJ', 'mark'), ('ilegais', None, 'ADJ', 'nsubj'), ('consigam', None, 'VERB', 'ccomp'), ('empregos', None, 'NOUN', 'obj'), ('nos', None, None, None), ('em', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('EUA', None, 'PROPN', 'obl'), ('e', None, 'CCONJ', 'cc'), ('a', None, 'DET', 'det'), ('suspensão', None, 'NOUN', 'conj'), ('de', None, 'ADP', 'case'), ('verbas', None, 'NOUN', 'nmod'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('governo', None, 'NOUN', 'nmod'), ('federal', None, 'ADJ', 'amod'), ('para', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('chamadas', None, 'ADJ', 'amod'), ('cidades-santuário', None, 'NOUN', 'nmod'), ('-', None, 'PUNCT', 'punct'), ('entre', None, 'ADP', 'case'), ('elas', None, 'PRON', 'acl'), ('Nova', None, 'PROPN', 'nsubj'), ('York', None, 'PROPN', 'flat:name'), (',', None, 'PUNCT', 'punct'), ('Los', None, 'PROPN', 'conj'), ('Angeles', None, 'PROPN', 'flat:name'), ('e', None, 'CCONJ', 'cc'), ('Chicago', None, 'PROPN', 'conj'), ('-', None, 'PUNCT', 'punct'), (',', None, 'PUNCT', 'punct'), ('que', None, 'PRON', 'nsubj'), ('se', None, 'PRON', 'expl'), ('recusam', None, 'VERB', 'acl:relcl'), ('a', None, 'ADP', 'mark'), ('seguir', None, 'VERB', 'xcomp'), ('a', None, 'DET', 'det'), ('política', None, 'NOUN', 'obj'), ('migratória', None, 'ADJ', 'amod'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('presidente', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 52 [('Na', None, None, None), ('Em', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('prioridade', None, 'NOUN', 'obl'), (',', None, 'PUNCT', 'punct'), ('caso', None, 'SCONJ', 'mark'), ('cancelem', None, 'VERB', 'advcl'), ('a', None, 'DET', 'det'), ('corrida', None, 'NOUN', 'obj'), (',', None, 'PUNCT', 'punct'), ('eles', None, 'PRON', 'nsubj:pass'), ('são', None, 'AUX', 'aux:pass'), ('colocados', None, 'VERB', 'root'), ('no', None, None, None), ('em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('fim', None, 'NOUN', 'obl'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('fila', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 53 [('Em', None, 'ADP', 'case'), ('2011', None, 'NUM', 'obl'), (',', None, 'PUNCT', 'punct'), ('Twain', None, 'PROPN', 'nsubj'), ('se', None, 'PRON', 'expl'), ('casou', None, 'VERB', 'root'), ('com', None, 'ADP', 'case'), ('Frédéric', None, 'PROPN', 'obl'), ('Thiébaud', None, 'PROPN', 'flat:name'), (',', None, 'PUNCT', 'punct'), ('o', None, 'DET', 'det'), ('ex-marido', None, 'NOUN', 'appos'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('amiga', None, 'NOUN', 'nmod'), ('com', None, 'ADP', 'case'), ('quem', None, 'PRON', 'obl'), ('seu', None, 'DET', 'det'), ('ex', None, 'NOUN', 'nsubj'), ('a', None, 'PRON', 'obj'), ('traiu', None, 'VERB', 'acl:relcl'), ('.', None, 'PUNCT', 'punct')]
# 54 [('No', None, None, None), ('Em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('segmento', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('médio', None, 'ADJ', 'amod'), ('e', None, 'CCONJ', 'cc'), ('alto', None, 'ADJ', 'conj'), ('padrão', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('os', None, 'DET', 'det'), ('lançamentos', None, 'NOUN', 'nsubj'), ('caíram', None, 'VERB', 'root'), ('13,7', None, 'NUM', 'nummod'), ('%', None, 'SYM', 'obj'), ('no', None, None, None), ('em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('acumulado', None, 'NOUN', 'obl'), ('até', None, 'ADP', 'case'), ('julho', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('e', None, 'CCONJ', 'cc'), ('as', None, 'DET', 'det'), ('entregas', None, 'NOUN', 'conj'), (',', None, 'PUNCT', 'punct'), ('55', None, 'NUM', 'nummod'), ('%', None, 'SYM', 'orphan'), ('.', None, 'PUNCT', 'punct')]
# 55 [('O', None, 'DET', 'det'), ('cinema', None, 'NOUN', 'nsubj'), ('pode', None, 'VERB', 'root'), ('ser', None, 'AUX', 'cop'), ('firme', None, 'ADJ', 'xcomp'), (',', None, 'PUNCT', 'punct'), ('fazer', None, 'VERB', 'conj'), ('uma', None, 'DET', 'det'), ('denúncia', None, 'NOUN', 'obj'), (',', None, 'PUNCT', 'punct'), ('trazer', None, 'VERB', 'conj'), ('um', None, 'DET', 'det'), ('questionamento', None, 'NOUN', 'obj'), ('.', None, 'PUNCT', 'punct')]
# 56 [('A', None, 'DET', 'det'), ('Cabify', None, 'PROPN', 'nsubj'), ('diz', None, 'VERB', 'root'), ('que', None, 'SCONJ', 'mark'), ('o', None, 'DET', 'det'), ('seu', None, 'DET', 'det'), ('motorista', None, 'NOUN', 'nsubj'), ('não', None, 'ADV', 'advmod'), ('tem', None, 'VERB', 'ccomp'), ('a', None, 'DET', 'det'), ('opção', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'mark'), ('cancelar', None, 'VERB', 'acl'), ('a', None, 'DET', 'det'), ('viagem', None, 'NOUN', 'obj'), ('no', None, None, None), ('em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('aeroporto', None, 'NOUN', 'obl'), (',', None, 'PUNCT', 'punct'), ('onde', None, 'ADV', 'advmod'), ('a', None, 'DET', 'det'), ('fila', None, 'NOUN', 'nsubj'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('aplicativo', None, 'NOUN', 'nmod'), ('existe', None, 'VERB', 'acl:relcl'), ('desde', None, 'ADP', 'case'), ('junho', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('2016', None, 'NUM', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 57 [('Mas', None, 'CCONJ', 'cc'), ('tenho', None, 'VERB', 'root'), ('certeza', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'mark'), ('que', None, 'SCONJ', 'fixed'), ('a', None, 'DET', 'det'), ('análise', None, 'NOUN', 'nsubj'), ('de', None, 'ADP', 'case'), ('diferença', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('PIB', None, 'PROPN', 'nmod'), ('per', None, 'X', 'nmod'), ('capita', None, 'X', 'flat:foreign'), ('também', None, 'ADV', 'advmod'), ('se', None, 'PRON', 'expl'), ('aplica', None, 'VERB', 'acl'), ('a', None, 'ADP', 'case'), ('esses', None, 'DET', 'det'), ('muros', None, 'NOUN', 'obl'), ('urbanos', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# 58 [('Na', None, None, None), ('Em', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('ocasião', None, 'NOUN', 'obl'), (',', None, 'PUNCT', 'punct'), ('Silvio', None, 'PROPN', 'nsubj'), ('sugeriu', None, 'VERB', 'root'), ('que', None, 'SCONJ', 'mark'), ('a', None, 'DET', 'det'), ('jovem', None, 'NOUN', 'nsubj'), ('de', None, 'ADP', 'case'), ('15', None, 'NUM', 'nummod'), ('anos', None, 'NOUN', 'nmod'), ('namorasse', None, 'VERB', 'ccomp'), ('o', None, 'DET', 'det'), ('apresentador', None, 'NOUN', 'obj'), ('Dudu', None, 'PROPN', 'nmod'), ('Camargo', None, 'PROPN', 'flat:name'), (',', None, 'PUNCT', 'punct'), ('19', None, 'NUM', 'parataxis'), (',', None, 'PUNCT', 'punct'), ('que', None, 'PRON', 'nsubj'), ('também', None, 'ADV', 'advmod'), ('participava', None, 'VERB', 'acl:relcl'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('atração', None, 'NOUN', 'obl'), ('.', None, 'PUNCT', 'punct')]
# 59 [('Não', None, 'ADV', 'advmod'), ('"', None, 'PUNCT', 'punct'), ('se', None, 'PRON', 'expl'), ('aposentar', None, 'VERB', 'root'), ('"', None, 'PUNCT', 'punct'), ('de', None, 'ADP', 'case'), ('tudo', None, 'PRON', 'obl'), (':', None, 'PUNCT', 'punct'), ('A', None, 'DET', 'det'), ('aposentadoria', None, 'NOUN', 'nsubj'), ('é', None, 'AUX', 'cop'), ('um', None, 'DET', 'det'), ('direito', None, 'NOUN', 'parataxis'), ('de', None, 'ADP', 'case'), ('todos', None, 'PRON', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 60 [('O', None, 'DET', 'det'), ('programa', None, 'NOUN', 'nsubj'), ('para', None, 'ADP', 'case'), ('famílias', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('baixa', None, 'ADJ', 'amod'), ('renda', None, 'NOUN', 'nmod'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('SO+MA', None, 'PROPN', 'nmod'), ('também', None, 'ADV', 'advmod'), ('dá', None, 'VERB', 'root'), ('benefícios', None, 'NOUN', 'obj'), ('a', None, 'ADP', 'case'), ('quem', None, 'PRON', 'obl'), ('recicla', None, 'VERB', 'acl:relcl'), ('.', None, 'PUNCT', 'punct')]
# 61 [('Já', None, 'CCONJ', 'cc'), ('o', None, 'DET', 'det'), ('Bordeaux', None, 'PROPN', 'nsubj'), ('segue', None, 'VERB', 'root'), ('com', None, 'ADP', 'case'), ('15', None, 'NUM', 'nummod'), ('pontos', None, 'NOUN', 'obl'), ('.', None, 'PUNCT', 'punct')]
# 62 [('A', None, 'DET', 'det'), ('produção', None, 'NOUN', 'nsubj'), ('global', None, 'ADJ', 'amod'), ('sobe', None, 'VERB', 'root'), ('para', None, 'ADP', 'case'), ('187,4', None, 'NUM', 'nummod'), ('milhões', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('toneladas', None, 'NOUN', 'nmod'), ('e', None, 'CCONJ', 'cc'), ('o', None, 'DET', 'det'), ('consumo', None, 'NOUN', 'nsubj'), ('será', None, 'AUX', 'cop'), ('de', None, 'ADP', 'case'), ('184,8', None, 'NUM', 'nummod'), ('milhões', None, 'NOUN', 'conj'), ('.', None, 'PUNCT', 'punct')]
# 63 [('Ela', None, 'PRON', 'nsubj:pass'), ('foi', None, 'AUX', 'aux:pass'), ('criticada', None, 'VERB', 'root'), ('nas', None, None, None), ('em', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('últimas', None, 'ADJ', 'amod'), ('décadas', None, 'NOUN', 'obl'), ('por', None, 'ADP', 'case'), ('sua', None, 'DET', 'det'), ('militância', None, 'NOUN', 'obl'), ('-', None, 'PUNCT', 'punct'), ('é', None, 'AUX', 'cop'), ('fundadora', None, 'NOUN', 'conj'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('revista', None, 'NOUN', 'nmod'), ('feminista', None, 'ADJ', 'amod'), ('"', None, 'PUNCT', 'punct'), ('Emma', None, 'PROPN', 'nmod'), ('"', None, 'PUNCT', 'punct'), (',', None, 'PUNCT', 'punct'), ('criada', None, 'VERB', 'acl'), ('em', None, 'ADP', 'case'), ('1977', None, 'NUM', 'obl'), ('.', None, 'PUNCT', 'punct')]
# 64 [('No', None, None, None), ('Em', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('"', None, 'PUNCT', 'punct'), ('Financial', None, 'PROPN', 'obl'), ('Times', None, 'PROPN', 'flat:name'), ('"', None, 'PUNCT', 'punct'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('fim', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('semana', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('"', None, 'PUNCT', 'punct'), ('Escândalos', None, 'NOUN', 'nsubj'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('Brasil', None, 'PROPN', 'nmod'), ('não', None, 'ADV', 'advmod'), ('amortecem', None, 'VERB', 'root'), ('espírito', None, 'NOUN', 'obj'), ('dos', None, None, None), ('de', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('investidores', None, 'NOUN', 'nmod'), ('"', None, 'PUNCT', 'punct'), ('.', None, 'PUNCT', 'punct')]
# 65 [('Um', None, 'DET', 'det'), ('sinal', None, 'NOUN', 'root'), ('de', None, 'ADP', 'mark'), ('que', None, 'SCONJ', 'fixed'), ('pode', None, 'VERB', 'acl'), ('haver', None, 'VERB', 'xcomp'), ('falhas', None, 'NOUN', 'obj'), ('graves', None, 'ADJ', 'amod'), ('e', None, 'CCONJ', 'cc'), ('desatualização', None, 'NOUN', 'conj'), ('nas', None, None, None), ('em', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('informações', None, 'NOUN', 'obl'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('último', None, 'ADJ', 'amod'), ('censo', None, 'NOUN', 'nmod'), ('agropecuário', None, 'ADJ', 'amod'), ('(', None, 'PUNCT', 'punct'), ('2006', None, 'NUM', 'parataxis'), (')', None, 'PUNCT', 'punct'), ('.', None, 'PUNCT', 'punct')]
# 66 [('É', None, 'AUX', 'cop'), ('aterrorizante', None, 'ADJ', 'ccomp:speech'), (',', None, 'PUNCT', 'punct'), ('desabafa', None, 'VERB', 'root'), ('a', None, 'DET', 'det'), ('sobrinha', None, 'NOUN', 'nsubj'), ('.', None, 'PUNCT', 'punct')]
# 67 [('Quando', None, 'SCONJ', 'mark'), ('se', None, 'PRON', 'expl'), ('apresentou', None, 'VERB', 'advcl'), ('ao', None, None, None), ('a', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('Santos', None, 'PROPN', 'obl'), (',', None, 'PUNCT', 'punct'), ('Nilmar', None, 'PROPN', 'nsubj'), ('não', None, 'ADV', 'advmod'), ('disputava', None, 'VERB', 'root'), ('uma', None, 'DET', 'det'), ('partida', None, 'NOUN', 'obj'), ('oficial', None, 'ADJ', 'amod'), ('havia', None, 'VERB', 'advcl'), ('14', None, 'NUM', 'nummod'), ('meses', None, 'NOUN', 'obj'), ('.', None, 'PUNCT', 'punct')]
# 68 [('O', None, 'DET', 'det'), ('valor', None, 'NOUN', 'nsubj'), ('bruto', None, 'ADJ', 'amod'), ('sai', None, 'VERB', 'root'), ('de', None, 'ADP', 'case'), ('R$', None, 'SYM', 'obl'), ('5.000', None, 'NUM', 'nummod'), ('para', None, 'ADP', 'case'), ('R$', None, 'SYM', 'nmod'), ('3.600', None, 'NUM', 'nummod'), ('.', None, 'PUNCT', 'punct')]
# 69 [('Quando', None, 'SCONJ', 'mark'), ('eu', None, 'PRON', 'nsubj'), ('vejo', None, 'VERB', 'advcl'), ('um', None, 'DET', 'det'), ('policial', None, 'NOUN', 'obj'), ('eu', None, 'PRON', 'nsubj'), ('penso', None, 'VERB', 'root'), (':', None, 'PUNCT', 'punct'), ('será', None, 'AUX', 'discourse'), ('que', None, 'SCONJ', 'discourse'), ('foi', None, 'AUX', 'cop'), ('um', None, 'NUM', 'ccomp:speech'), ('desses', None, None, None), ('de', None, 'ADP', 'case'), ('esses', None, 'PRON', 'nmod'), ('que', None, 'PRON', 'nsubj'), ('matou', None, 'VERB', 'acl:relcl'), ('?', None, 'PUNCT', 'punct')]
# 70 [('Da', None, None, None), ('De', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('soberania', None, 'NOUN', 'root'), ('popular', None, 'ADJ', 'amod'), ('que', None, 'PRON', 'nsubj'), ('se', None, 'PRON', 'expl'), ('manifesta', None, 'VERB', 'acl:relcl'), ('por', None, 'ADP', 'case'), ('iniciativas', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('projetos', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('leis', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 71 [('Temos', None, 'VERB', 'root'), ('hoje', None, 'ADV', 'advmod'), ('300', None, 'NUM', 'nummod'), ('corretoras', None, 'NOUN', 'obj'), ('e', None, 'CCONJ', 'cc'), ('consultorias', None, 'NOUN', 'conj'), ('.', None, 'PUNCT', 'punct')]
# 72 [('Eu', None, 'PRON', 'nsubj'), ('cheguei', None, 'VERB', 'root'), ('na', None, None, None), ('em', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('Warner', None, 'PROPN', 'obl'), ('já', None, 'ADV', 'advmod'), ('com', None, 'ADP', 'case'), ('outro', None, 'DET', 'det'), ('status', None, 'NOUN', 'obl'), (',', None, 'PUNCT', 'punct'), ('outro', None, 'DET', 'det'), ('percentual', None, 'NOUN', 'conj'), ('de', None, 'ADP', 'case'), ('royalties', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('tudo', None, 'PRON', 'parataxis'), ('já', None, 'ADV', 'advmod'), ('diferente', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# ...
# 1662 [('Ela', None, 'PRON', 'root'), (',', None, 'PUNCT', 'punct'), ('a', None, 'DET', 'det'), ('chefe', None, 'NOUN', 'appos'), ('de', None, 'ADP', 'case'), ('polícia', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('Dooling', None, 'PROPN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 1663 [('Depois', None, 'ADV', 'advmod'), (',', None, 'PUNCT', 'punct'), ('jogue-se', None, None, None), ('jogue', None, 'VERB', 'root'), ('se', None, 'PRON', 'expl'), ('em', None, 'ADP', 'case'), ('itens', None, 'NOUN', 'obl'), ('como', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('tradicional', None, 'ADJ', 'amod'), ('faláfel', None, 'X', 'nmod'), ('e', None, 'CCONJ', 'cc'), ('a', None, 'DET', 'det'), ('salada', None, 'NOUN', 'conj'), ('fatouche', None, 'X', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 1664 [('Os', None, 'DET', 'det'), ('cadáveres', None, 'NOUN', 'nsubj'), (',', None, 'PUNCT', 'punct'), ('que', None, 'PRON', 'nsubj'), ('estão', None, 'AUX', 'cop'), ('por', None, 'ADP', 'case'), ('todos', None, 'DET', 'det'), ('os', None, 'DET', 'det'), ('lados', None, 'NOUN', 'acl:relcl'), (',', None, 'PUNCT', 'punct'), ('lembram', None, 'VERB', 'root'), ('a', None, 'ADP', 'case'), ('todo', None, 'DET', 'det'), ('momento', None, 'NOUN', 'obl'), ('cifras', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'case'), ('um', None, 'DET', 'det'), ('genocídio', None, 'NOUN', 'nmod'), ('que', None, 'PRON', 'nsubj'), ('dizimou', None, 'VERB', 'acl:relcl'), ('um', None, 'NUM', 'nummod'), ('quarto', None, 'NOUN', 'obj'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('população', None, 'NOUN', 'nmod'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('país', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 1665 [('A', None, 'DET', 'det'), ('consultora', None, 'NOUN', 'nsubj'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('Sebrae', None, 'PROPN', 'nmod'), ('sugere', None, 'VERB', 'root'), (',', None, 'PUNCT', 'punct'), ('para', None, 'ADP', 'mark'), ('quem', None, 'PRON', 'obl'), ('não', None, 'ADV', 'advmod'), ('tem', None, 'VERB', 'acl:relcl'), ('muita', None, 'ADJ', 'amod'), ('verba', None, 'NOUN', 'obj'), (',', None, 'PUNCT', 'punct'), ('entrar', None, 'VERB', 'ccomp'), ('em', None, 'ADP', 'case'), ('contato', None, 'NOUN', 'obl'), ('com', None, 'ADP', 'case'), ('empresas', None, 'NOUN', 'nmod'), ('juniores', None, 'ADJ', 'amod'), ('na', None, None, None), ('em', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('área', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('design', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('"', None, 'PUNCT', 'punct'), ('que', None, 'PRON', 'nsubj'), ('podem', None, 'VERB', 'acl:relcl'), ('ajudar', None, 'VERB', 'xcomp'), ('a', None, 'ADP', 'mark'), ('criar', None, 'VERB', 'xcomp'), ('um', None, 'DET', 'det'), ('material', None, 'NOUN', 'obj'), ('bonito', None, 'ADJ', 'amod'), ('e', None, 'CCONJ', 'cc'), ('funcional', None, 'ADJ', 'conj'), ('"', None, 'PUNCT', 'punct'), ('.', None, 'PUNCT', 'punct')]
# 1666 [('Logo', None, 'ADV', 'advmod'), ('nas', None, None, None), ('em', None, 'ADP', 'case'), ('as', None, 'DET', 'det'), ('respostas', None, 'NOUN', 'obl'), ('iniciais', None, 'ADJ', 'amod'), (',', None, 'PUNCT', 'punct'), ('Doria', None, 'PROPN', 'nsubj'), ('destacou', None, 'VERB', 'root'), ('o', None, 'DET', 'det'), ('fato', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'mark'), ('ter', None, 'AUX', 'aux'), ('permanecido', None, 'VERB', 'acl'), ('junto', None, 'ADV', 'advmod'), ('ao', None, None, None), ('a', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('governador', None, 'NOUN', 'obl'), ('na', None, None, None), ('em', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('cerimônia', None, 'NOUN', 'obl'), ('.', None, 'PUNCT', 'punct')]
# 1667 [('Entre', None, 'ADP', 'case'), ('elas', None, 'PRON', 'root'), ('está', None, 'AUX', 'cop'), ('Kirkuk', None, 'PROPN', 'nsubj'), (',', None, 'PUNCT', 'punct'), ('cidade', None, 'NOUN', 'appos'), ('produtora', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('petróleo', None, 'NOUN', 'nmod'), ('com', None, 'ADP', 'case'), ('população', None, 'NOUN', 'nmod'), ('árabe', None, 'ADJ', 'amod'), (',', None, 'PUNCT', 'punct'), ('cristã', None, 'ADJ', 'conj'), ('e', None, 'CCONJ', 'cc'), ('turcomena', None, 'ADJ', 'conj'), (',', None, 'PUNCT', 'punct'), ('contrária', None, 'ADJ', 'amod'), ('ao', None, None, None), ('a', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('domínio', None, 'NOUN', 'obl'), ('curdo', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# 1668 [('Nosso', None, 'DET', 'det'), ('ambiente', None, 'NOUN', 'nsubj'), ('de', None, 'ADP', 'case'), ('negócios', None, 'NOUN', 'nmod'), ('está', None, 'AUX', 'cop'), ('longe', None, 'ADV', 'root'), ('de', None, 'ADP', 'mark'), ('ser', None, 'AUX', 'cop'), ('animador', None, 'ADJ', 'acl'), (',', None, 'PUNCT', 'punct'), ('ainda', None, 'ADV', 'mark'), ('que', None, 'SCONJ', 'fixed'), ('o', None, 'DET', 'det'), ('país', None, 'NOUN', 'nsubj'), ('possa', None, 'VERB', 'advcl'), ('ser', None, 'AUX', 'aux:pass'), ('considerado', None, 'VERB', 'xcomp'), ('um', None, 'DET', 'det'), ('campo', None, 'NOUN', 'xcomp'), ('fértil', None, 'ADJ', 'amod'), ('para', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('desenvolvimento', None, 'NOUN', 'nmod'), ('de', None, 'ADP', 'case'), ('inúmeras', None, 'DET', 'det'), ('atividades', None, 'NOUN', 'nmod'), ('econômicas', None, 'ADJ', 'amod'), ('que', None, 'PRON', 'nsubj'), ('estão', None, 'AUX', 'cop'), ('com', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('potencial', None, 'NOUN', 'acl:relcl'), ('esgotado', None, 'ADJ', 'amod'), ('em', None, 'ADP', 'case'), ('economias', None, 'NOUN', 'nmod'), ('ricas', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# 1669 [('Outros', None, 'DET', 'det'), ('dois', None, 'NUM', 'nummod'), ('temas', None, 'NOUN', 'nsubj'), ('de', None, 'ADP', 'case'), ('grande', None, 'ADJ', 'amod'), ('temor', None, 'NOUN', 'nmod'), ('internacional', None, 'ADJ', 'amod'), ('-', None, 'PUNCT', 'punct'), ('a', None, 'DET', 'det'), ('crise', None, 'NOUN', 'appos'), ('na', None, None, None), ('em', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('Venezuela', None, 'PROPN', 'nmod'), ('e', None, 'CCONJ', 'cc'), ('a', None, 'DET', 'det'), ('violência', None, 'NOUN', 'conj'), ('contra', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('minoria', None, 'NOUN', 'nmod'), ('étnica', None, 'ADJ', 'amod'), ('rohingya', None, 'NOUN', 'nmod'), ('em', None, 'ADP', 'case'), ('Mianmar', None, 'PROPN', 'nmod'), ('-', None, 'PUNCT', 'punct'), ('serão', None, 'AUX', 'aux:pass'), ('discutidos', None, 'VERB', 'root'), ('sem', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('presença', None, 'NOUN', 'obl'), ('dos', None, None, None), ('de', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('líderes', None, 'NOUN', 'nmod'), ('desses', None, None, None), ('de', None, 'ADP', 'case'), ('esses', None, 'DET', 'det'), ('países', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 1670 [('O', None, 'DET', 'det'), ('elemento', None, 'NOUN', 'nsubj'), ('novo', None, 'ADJ', 'amod'), ('é', None, 'AUX', 'cop'), ('o', None, 'DET', 'det'), ('próprio', None, 'DET', 'det'), ('Macron', None, 'PROPN', 'root'), (',', None, 'PUNCT', 'punct'), ('que', None, 'PRON', 'nsubj'), ('quer', None, 'VERB', 'acl:relcl'), ('convocar', None, 'VERB', 'xcomp'), ('uma', None, 'DET', 'det'), ('consulta', None, 'NOUN', 'obj'), ('aos', None, None, None), ('a', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('cidadãos', None, 'NOUN', 'nmod'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('bloco', None, 'NOUN', 'nmod'), ('para', None, 'ADP', 'mark'), ('entender', None, 'VERB', 'advcl'), ('seus', None, 'DET', 'det'), ('descontentamentos', None, 'NOUN', 'obj'), ('.', None, 'PUNCT', 'punct')]
# 1671 [('Mais', None, 'DET', 'det'), ('terras', None, 'NOUN', 'nsubj:pass'), ('federais', None, 'ADJ', 'amod'), ('foram', None, 'AUX', 'aux:pass'), ('abertas', None, 'VERB', 'root'), ('à', None, None, None), ('a', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('extração', None, 'NOUN', 'obl'), ('de', None, 'ADP', 'case'), ('carvão', None, 'NOUN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 1672 [('E', None, 'CCONJ', 'cc'), ('segue', None, 'VERB', 'root'), (':', None, 'PUNCT', 'punct'), ('[', None, 'PUNCT', 'punct'), ('As', None, 'DET', 'det'), ('pessoas', None, 'NOUN', 'nsubj'), (']', None, 'PUNCT', 'punct'), ('têm', None, 'VERB', 'ccomp:speech'), ('o', None, 'DET', 'det'), ('direito', None, 'NOUN', 'obj'), ('de', None, 'ADP', 'mark'), ('escolher', None, 'VERB', 'acl'), ('seus', None, 'DET', 'det'), ('caminhos', None, 'NOUN', 'obj'), (',', None, 'PUNCT', 'punct'), ('como', None, 'ADV', 'advmod'), ('querem', None, 'VERB', 'conj'), ('ser', None, 'AUX', 'xcomp'), ('.', None, 'PUNCT', 'punct')]
# 1673 [('Seus', None, 'DET', 'det'), ('apoiadores', None, 'NOUN', 'nsubj'), (',', None, 'PUNCT', 'punct'), ('contudo', None, 'CCONJ', 'cc'), (',', None, 'PUNCT', 'punct'), ('retrucarão', None, 'VERB', 'root'), (',', None, 'PUNCT', 'punct'), ('afirmando', None, 'VERB', 'advcl'), ('que', None, 'SCONJ', 'mark'), ('Janot', None, 'PROPN', 'nsubj'), ('deu', None, 'VERB', 'ccomp'), ('ao', None, None, None), ('a', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('Ministério', None, 'PROPN', 'obl'), ('Público', None, 'PROPN', 'flat:name'), ('Federal', None, 'PROPN', 'flat:name'), ('um', None, 'DET', 'det'), ('protagonismo', None, 'NOUN', 'obj'), ('jamais', None, 'ADV', 'advmod'), ('alcançado', None, 'VERB', 'acl'), ('e', None, 'CCONJ', 'cc'), ('que', None, 'SCONJ', 'mark'), ('nem', None, 'ADV', 'advmod'), ('todos', None, 'PRON', 'nsubj'), ('poderiam', None, 'VERB', 'conj'), ('ter', None, 'AUX', 'aux'), ('aguentado', None, 'VERB', 'xcomp'), ('as', None, 'DET', 'det'), ('pressões', None, 'NOUN', 'obj'), ('que', None, 'PRON', 'obj'), ('suportou', None, 'VERB', 'acl:relcl'), ('.', None, 'PUNCT', 'punct')]
# 1674 [('Nossa', None, 'INTJ', 'discourse'), (',', None, 'PUNCT', 'punct'), ('acho', None, 'VERB', 'root'), ('que', None, 'SCONJ', 'mark'), ('estou', None, 'AUX', 'cop'), ('confusa', None, 'ADJ', 'ccomp'), ('.', None, 'PUNCT', 'punct')]
# 1675 [('Gradualmente', None, 'ADV', 'advmod'), (',', None, 'PUNCT', 'punct'), ('Guarda', None, 'PROPN', 'nsubj'), ('concretizava-se', None, None, None), ('concretizava', None, 'VERB', 'root'), ('se', None, 'PRON', 'expl'), ('como', None, 'ADP', 'case'), ('lembrança', None, 'NOUN', 'obl'), (',', None, 'PUNCT', 'punct'), ('não', None, 'ADV', 'advmod'), ('projeto', None, 'NOUN', 'conj'), ('.', None, 'PUNCT', 'punct')]
# 1676 [('Paul', None, 'PROPN', 'nsubj'), ('deve', None, 'VERB', 'root'), ('transformar', None, 'VERB', 'xcomp'), ('a', None, 'DET', 'det'), ('plateia', None, 'NOUN', 'obj'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('Allianz', None, 'PROPN', 'nmod'), ('Parque', None, 'PROPN', 'flat:name'), ('num', None, None, None), ('em', None, 'ADP', 'case'), ('um', None, 'DET', 'det'), ('karaokê', None, 'NOUN', 'obl'), ('gigante', None, 'ADJ', 'amod'), (',', None, 'PUNCT', 'punct'), ('principalmente', None, 'ADV', 'advmod'), ('na', None, None, None), ('em', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('parte', None, 'NOUN', 'obl'), ('final', None, 'ADJ', 'amod'), ('do', None, None, None), ('de', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('show', None, 'NOUN', 'nmod'), (',', None, 'PUNCT', 'punct'), ('quando', None, 'ADV', 'advmod'), ('emenda', None, 'VERB', 'acl:relcl'), ('uns', None, 'DET', 'det'), ('oito', None, 'NUM', 'nummod'), ('sucessos', None, 'NOUN', 'obj'), ('dos', None, None, None), ('de', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('Beatles', None, 'PROPN', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 1677 [('Do', None, None, None), ('De', None, 'ADP', 'case'), ('o', None, 'DET', 'det'), ('valor', None, 'NOUN', 'obl'), ('pago', None, 'VERB', 'acl'), ('durante', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('Lava', None, 'PROPN', 'obl'), ('Jato', None, 'PROPN', 'flat:name'), (',', None, 'PUNCT', 'punct'), ('R$', None, 'SYM', 'nmod'), ('1,3', None, 'NUM', 'nummod'), ('milhão', None, 'NOUN', 'nsubj:pass'), ('foram', None, 'AUX', 'aux:pass'), ('entregues', None, 'VERB', 'root'), ('por', None, 'ADP', 'case'), ('Funaro', None, 'PROPN', 'obl:agent'), ('quando', None, 'SCONJ', 'mark'), ('Cunha', None, 'PROPN', 'nsubj'), ('era', None, 'AUX', 'cop'), ('o', None, 'DET', 'det'), ('presidente', None, 'NOUN', 'advcl'), ('da', None, None, None), ('de', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('Câmara', None, 'PROPN', 'nmod'), ('dos', None, None, None), ('de', None, 'ADP', 'case'), ('os', None, 'DET', 'det'), ('Deputados', None, 'PROPN', 'flat:name'), (',', None, 'PUNCT', 'punct'), ('em', None, 'ADP', 'case'), ('2015', None, 'NUM', 'nmod'), ('.', None, 'PUNCT', 'punct')]
# 1678 [('Julia', None, 'PROPN', 'nsubj'), ('Louis-Dreyfus', None, 'PROPN', 'flat:name'), ('ganhou', None, 'VERB', 'root'), ('pela', None, None, None), ('por', None, 'ADP', 'case'), ('a', None, 'DET', 'det'), ('sexta', None, 'ADJ', 'amod'), ('vez', None, 'NOUN', 'obl'), ('consecutiva', None, 'ADJ', 'amod'), ('o', None, 'DET', 'det'), ('troféu', None, 'NOUN', 'obj'), ('por', None, 'ADP', 'case'), ('sua', None, 'DET', 'det'), ('atuação', None, 'NOUN', 'obl'), ('em', None, 'ADP', 'case'), ('"', None, 'PUNCT', 'punct'), ('Veep', None, 'PROPN', 'nmod'), ('"', None, 'PUNCT', 'punct'), (',', None, 'PUNCT', 'punct'), ('um', None, 'DET', 'det'), ('recorde', None, 'NOUN', 'parataxis'), ('.', None, 'PUNCT', 'punct')]
# 1679 [('Até', None, 'ADV', 'advmod'), ('a', None, 'DET', 'det'), ('família', None, 'NOUN', 'nsubj'), ('julga', None, 'VERB', 'ccomp:speech'), ('mais', None, 'ADV', 'advmod'), ('e', None, 'CCONJ', 'cc'), ('apoia', None, 'VERB', 'conj'), ('menos', None, 'ADV', 'advmod'), ('quando', None, 'SCONJ', 'mark'), ('a', None, 'DET', 'det'), ('paciente', None, 'NOUN', 'nsubj'), ('é', None, 'AUX', 'cop'), ('mulher', None, 'NOUN', 'advcl'), (',', None, 'PUNCT', 'punct'), ('explica', None, 'VERB', 'root'), ('Tissot', None, 'PROPN', 'nsubj'), ('.', None, 'PUNCT', 'punct')]
# 1680 [('Mas', None, 'CCONJ', 'cc'), ('há', None, 'VERB', 'root'), ('episódios', None, 'NOUN', 'obj'), ('que', None, 'PRON', 'nsubj'), ('indicam', None, 'VERB', 'acl:relcl'), ('em', None, 'ADP', 'case'), ('Damião', None, 'PROPN', 'obl'), ('um', None, 'DET', 'det'), ('comportamento', None, 'NOUN', 'obj'), ('estranho', None, 'ADJ', 'amod'), ('.', None, 'PUNCT', 'punct')]
# 1681 [('"', None, 'PUNCT', 'punct'), ('Mas', None, 'CCONJ', 'cc'), ('Che', None, 'PROPN', 'nsubj'), ('permanece', None, 'VERB', 'ccomp:speech'), ('puro', None, 'ADJ', 'xcomp'), (',', None, 'PUNCT', 'punct'), ('de', None, 'ADP', 'case'), ('certo', None, 'DET', 'det'), ('modo', None, 'NOUN', 'obl'), ('"', None, 'PUNCT', 'punct'), (',', None, 'PUNCT', 'punct'), ('ele', None, 'PRON', 'nsubj'), ('disse', None, 'VERB', 'root'), ('.', None, 'PUNCT', 'punct')]
# 1682 [('E', None, 'CCONJ', 'cc'), ('a', None, 'DET', 'det'), ('grande', None, 'ADJ', 'amod'), ('dúvida', None, 'NOUN', 'nsubj:outer'), ('é', None, 'AUX', 'cop'), ('se', None, 'SCONJ', 'mark'), ('essas', None, 'DET', 'det'), ('cicatrizes', None, 'NOUN', 'nsubj'), ('vão', None, 'AUX', 'aux'), ('realmente', None, 'ADV', 'advmod'), ('sarar', None, 'VERB', 'root'), ('.', None, 'PUNCT', 'punct')]

# %%
frases
